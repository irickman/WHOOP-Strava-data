# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split as tts
import statsmodels.api as sm

# %matplotlib inline
pd.options.display.max_rows=100
pd.options.display.max_columns=100

# %%
whoop=pd.read_csv('../Data/whoop_data.csv')

# %%
strava=pd.read_csv('../Data/my_actvities.csv')

# %%
strava.shape, whoop.shape
# Out:
# ((173, 35), (222, 12))

# %%
mult_mile=0.000621371
strava['miles']=strava.distance*mult_mile

# %% [markdown]
# ## Whoop data discovery

# %%
whoop.head()
# Out:
#   strain recovery sleep_perf  sleep rec_sleep            date     activity_1  \
# 0   17.3      78%       100%  10:02      8:40  Today, Jan 4th        Running
# 1   12.8      50%        86%   8:27      9:52    Thu, Jan 3rd  Weightlifting
# 2   17.6      28%        69%   6:09      8:55    Wed, Jan 2nd        Running
# 3   18.1      37%        96%   7:44      8:04    Tue, Jan 1st        Running
# 4   12.1      36%       100%   9:53      8:37   Mon, Dec 31st            NaN
#
#    activity_1_score activity_2  activity_2_score activity_3  activity_3_score
# 0              15.4        NaN               NaN        NaN               NaN
# 1               7.0        NaN               NaN        NaN               NaN
# 2              16.3        NaN               NaN        NaN               NaN
# 3              15.7   Activity               7.3        NaN               NaN
# 4               NaN        NaN               NaN        NaN               NaN

# %%
whoop.recovery.value_counts()
# Out:
# 24%                 8
# 36%                 7
# 32%                 7
# 27%                 6
# 85%                 6
# 30%                 6
# 25%                 6
# 49%                 6
# 37%                 6
# 16%                 5
# 28%                 5
# 44%                 5
# 21%                 5
# 35%                 5
# 63%                 5
# 38%                 5
# 75%                 4
# 48%                 4
# 94%                 4
# 26%                 4
# 18%                 4
# 34%                 4
# 33%                 4
# 69%                 4
# 61%                 4
# 89%                 3
# 19%                 3
# 29%                 3
# 13%                 3
# 54%                 3
# 17%                 3
# Incomplete\nData    3
# 59%                 3
# 60%                 3
# 46%                 3
# ---                 2
# 39%                 2
# 58%                 2
# 70%                 2
# 20%                 2
# 23%                 2
# 93%                 2
# 86%                 2
# 87%                 2
# 78%                 2
# 41%                 2
# 82%                 2
# 47%                 2
# 67%                 2
# 11%                 2
# 55%                 2
# 95%                 2
# 40%                 1
# 12%                 1
# 43%                 1
# 22%                 1
# 90%                 1
# 88%                 1
# 64%                 1
# 76%                 1
# 96%                 1
# 68%                 1
# 52%                 1
# 97%                 1
# 56%                 1
# 74%                 1
# 62%                 1
# 77%                 1
# 14%                 1
# 5%                  1
# 92%                 1
# 81%                 1
# 57%                 1
# Pending             1
# 42%                 1
# 72%                 1
# 83%                 1
# 50%                 1
# 31%                 1
# 84%                 1
# 45%                 1
# Name: recovery, dtype: int64

# %%
print(whoop.activity_1.value_counts())
print(whoop.activity_2.value_counts())
print(whoop.activity_3.value_counts())
# Out:
# Running               69
# Cycling               26
# Swimming              15
# Weightlifting          6
# Activity               5
# Hiking/Rucking         3
# Triathlon              2
# Other                  2
# Functional Fitness     1
# Golf                   1
# Soccer                 1
# Football               1
# Name: activity_1, dtype: int64
# Running     9
# Activity    6
# Cycling     4
# Swimming    3
# Other       2
# Name: activity_2, dtype: int64
# Cycling    4
# Running    1
# Other      1
# Name: activity_3, dtype: int64

# %%
whoop['recovery']=whoop['recovery'].astype(str).apply(lambda x: np.nan if '%' not in x else float(x[:len(x)-1])/100)
whoop['sleep_perf']=whoop['sleep_perf'].astype(str).apply(lambda x: np.nan if '-' in x or "na" in x else float(x[:len(x)-1])/100)

# %%
whoop['rec_color']=whoop.recovery.apply(lambda x: 'red' if x<.34 else ('yellow' if x<.67 else ('none' if np.isnan(x) else 'green') ))
whoop.rec_color.value_counts()
# Out:
# yellow    83
# red       83
# green     50
# none       6
# Name: rec_color, dtype: int64

# %%
whoop.head()
# Out:
#   strain  recovery  sleep_perf  sleep rec_sleep            date  \
# 0   17.3      0.78        1.00  10:02      8:40  Today, Jan 4th
# 1   12.8      0.50        0.86   8:27      9:52    Thu, Jan 3rd
# 2   17.6      0.28        0.69   6:09      8:55    Wed, Jan 2nd
# 3   18.1      0.37        0.96   7:44      8:04    Tue, Jan 1st
# 4   12.1      0.36        1.00   9:53      8:37   Mon, Dec 31st
#
#       activity_1  activity_1_score activity_2  activity_2_score activity_3  \
# 0        Running              15.4        NaN               NaN        NaN
# 1  Weightlifting               7.0        NaN               NaN        NaN
# 2        Running              16.3        NaN               NaN        NaN
# 3        Running              15.7   Activity               7.3        NaN
# 4            NaN               NaN        NaN               NaN        NaN
#
#    activity_3_score rec_color
# 0               NaN     green
# 1               NaN    yellow
# 2               NaN       red
# 3               NaN    yellow
# 4               NaN    yellow

# %%
whoop.strain=whoop.strain.apply(lambda x: float(x) if x!="---" else 0)
plt.hist(whoop.strain)
# Out:
# (array([ 1.,  0.,  1., 10., 27., 39., 47., 40., 36., 21.]),
#  array([ 0.  ,  2.07,  4.14,  6.21,  8.28, 10.35, 12.42, 14.49, 16.56,
#         18.63, 20.7 ]),
#  <a list of 10 Patch objects>)

# %%
for i in range(1,8):
    print(whoop.recovery.autocorr(lag=i))
# Out:
# 0.01339240935736611
# 0.04043527262019506
# 0.12884124388214863
# 0.0557647046489472
# -0.015350577169256781
# -0.015275776233907717
# 0.08873767330893535

# %%
whoop.dtypes
# Out:
# strain              float64
# recovery            float64
# sleep_perf          float64
# sleep                object
# rec_sleep            object
# date                 object
# activity_1           object
# activity_1_score    float64
# activity_2           object
# activity_2_score    float64
# activity_3           object
# activity_3_score    float64
# rec_color            object
# dtype: object

# %%
def time_to_dec(t):
    if ":" in t:
        hr=float(t[:t.find(':')])
        m=float(t[t.find(':')+1:])/60
        return hr+m
    else:
        return np.nan
whoop.sleep=whoop.sleep.astype(str).apply(time_to_dec)
whoop.rec_sleep=whoop.rec_sleep.astype(str).apply(time_to_dec)

# %%
whoop.head()
# Out:
#    strain  recovery  sleep_perf      sleep  rec_sleep            date  \
# 0    17.3      0.78        1.00  10.033333   8.666667  Today, Jan 4th
# 1    12.8      0.50        0.86   8.450000   9.866667    Thu, Jan 3rd
# 2    17.6      0.28        0.69   6.150000   8.916667    Wed, Jan 2nd
# 3    18.1      0.37        0.96   7.733333   8.066667    Tue, Jan 1st
# 4    12.1      0.36        1.00   9.883333   8.616667   Mon, Dec 31st
#
#       activity_1  activity_1_score activity_2  activity_2_score activity_3  \
# 0        Running              15.4        NaN               NaN        NaN
# 1  Weightlifting               7.0        NaN               NaN        NaN
# 2        Running              16.3        NaN               NaN        NaN
# 3        Running              15.7   Activity               7.3        NaN
# 4            NaN               NaN        NaN               NaN        NaN
#
#    activity_3_score rec_color
# 0               NaN     green
# 1               NaN    yellow
# 2               NaN       red
# 3               NaN    yellow
# 4               NaN    yellow

# %% [markdown]
# ### Making Variables

# %%
whoop['activity_total']=whoop[['activity_1_score','activity_2_score','activity_3_score']].apply(lambda x: sum([0 if np.isnan(y) else 1 for y in x ]),axis=1 )
whoop.activity_total.value_counts()
# Out:
# 1    108
# 0     90
# 2     18
# 3      6
# Name: activity_total, dtype: int64

# %%
whoop['sleep_addition']=whoop.rec_sleep-7.75

# %%
whoop['pday_rec']=whoop['recovery'].shift(-1)
whoop['pday_rec_col']=whoop['rec_color'].shift(-1)
whoop['pday_acts']=whoop['activity_total'].shift(-1)
whoop['pday_strain']=whoop['strain']
whoop['pday_sleep']=whoop.sleep.shift(-1)
whoop['pday_sleep_perf']=whoop.sleep_perf.shift(-1)

# %%
whoop['rolling_prev_2']=whoop.pday_sleep.rolling(2).mean()
whoop['prev_strain_rec_gap']=whoop.pday_strain/whoop.pday_strain.max()-whoop.pday_rec

# %%
palet={'green':'green','yellow':'yellow','green':'green','none':'black','red':'red'}
sns.scatterplot('pday_strain','recovery',data=whoop, hue='pday_rec_col',
                hue_order=['green','yellow','red','none'],
               palette=palet)
plt.legend(bbox_to_anchor=(1,1))

# %%
whoop.head()
# Out:
#    strain  recovery  sleep_perf      sleep  rec_sleep            date  \
# 0    17.3      0.78        1.00  10.033333   8.666667  Today, Jan 4th
# 1    12.8      0.50        0.86   8.450000   9.866667    Thu, Jan 3rd
# 2    17.6      0.28        0.69   6.150000   8.916667    Wed, Jan 2nd
# 3    18.1      0.37        0.96   7.733333   8.066667    Tue, Jan 1st
# 4    12.1      0.36        1.00   9.883333   8.616667   Mon, Dec 31st
#
#       activity_1  activity_1_score activity_2  activity_2_score activity_3  \
# 0        Running              15.4        NaN               NaN        NaN
# 1  Weightlifting               7.0        NaN               NaN        NaN
# 2        Running              16.3        NaN               NaN        NaN
# 3        Running              15.7   Activity               7.3        NaN
# 4            NaN               NaN        NaN               NaN        NaN
#
#    activity_3_score rec_color  activity_total  sleep_addition  pday_rec  \
# 0               NaN     green               1        0.916667      0.50
# 1               NaN    yellow               1        2.116667      0.28
# 2               NaN       red               1        1.166667      0.37
# 3               NaN    yellow               2        0.316667      0.36
# 4               NaN    yellow               0        0.866667      0.16
#
#   pday_rec_col  pday_acts  pday_strain  pday_sleep  pday_sleep_perf  \
# 0       yellow        1.0         17.3    8.450000             0.86
# 1          red        1.0         12.8    6.150000             0.69
# 2       yellow        2.0         17.6    7.733333             0.96
# 3       yellow        0.0         18.1    9.883333             1.00
# 4          red        1.0         12.1    5.583333             0.63
#
#    rolling_prev_2  prev_strain_rec_gap
# 0             NaN             0.335749
# 1        7.300000             0.338357
# 2        6.941667             0.480242
# 3        8.808333             0.514396
# 4        7.733333             0.424541

# %%
whoop.date.tail()
# Out:
# 217     Fri, Jun 1st
# 218    Thu, May 31st
# 219    Wed, May 30th
# 220    Tue, May 29th
# 221    Mon, May 28th
# Name: date, dtype: object

# %%
strava.head()
# Out:
#    achievement_count  athlete_count  average_speed  average_watts  \
# 0                  3              1          3.324            NaN
# 1                  0              9          3.973            NaN
# 2                  0              1          2.963            NaN
# 3                  3              1          2.963            NaN
# 4                  0              1          0.753            NaN
#
#    comment_count  commute device_watts  distance  elapsed_time  elev_high  \
# 0              0    False          NaN    9266.8          2810      118.6
# 1              0    False          NaN    5530.9          2004       77.8
# 2              0    False          NaN    4865.8          1736       73.6
# 3              0    False          NaN    9666.4          4090       33.8
# 4              2    False          NaN     868.7          3623        NaN
#
#    elev_low             external_id  flagged  gear_id  has_kudoed          id  \
# 0      57.2  garmin_push_2594081397    False      NaN       False  1483967793
# 1      67.8  garmin_push_2597882997    False      NaN       False  1486944143
# 2      54.8  garmin_push_2600153736    False      NaN       False  1488794733
# 3      11.2  garmin_push_2602353832    False      NaN       False  1490564237
# 4       NaN  garmin_push_2605726138    False      NaN       False  1493353473
#
#    kilojoules  kudos_count  manual  max_speed  max_watts  moving_time  \
# 0         NaN            5   False        4.5        NaN         2788
# 1         NaN            7   False        6.2        NaN         1392
# 2         NaN            2   False       13.4        NaN         1642
# 3         NaN            3   False        8.2        NaN         3262
# 4         NaN            3   False        0.9        NaN         1153
#
#              name  photo_count  private                 start_date  \
# 0     Morning Run            0    False  2018-04-01 15:54:18+00:00
# 1     Morning Run            0    False  2018-04-03 10:35:19+00:00
# 2     Morning Run            0    False  2018-04-04 10:58:33+00:00
# 3     Morning Run            0    False  2018-04-05 10:29:13+00:00
# 4  Afternoon Swim            0    False  2018-04-06 21:56:04+00:00
#
#             start_date_local                         timezone  \
# 0  2018-04-01 08:54:18+00:00  (GMT-08:00) America/Los_Angeles
# 1  2018-04-03 06:35:19+00:00     (GMT-05:00) America/New_York
# 2  2018-04-04 06:58:33+00:00     (GMT-05:00) America/New_York
# 3  2018-04-05 06:29:13+00:00     (GMT-05:00) America/New_York
# 4  2018-04-06 17:56:04+00:00     (GMT-05:00) America/New_York
#
#    total_elevation_gain  total_photo_count  trainer  type   upload_id  \
# 0                  91.0                  0    False   Run  1598845934
# 1                  30.0                  0    False   Run  1601956509
# 2                  27.0                  0    False   Run  1603863011
# 3                  65.0                  0    False   Run  1605677780
# 4                   0.0                  0     True  Swim  1608556019
#
#    weighted_average_watts  workout_type     miles day month  year date_string  \
# 0                     NaN           NaN  5.758121  01    04  2018  2018-04-01
# 1                     NaN           NaN  3.436741  03    04  2018  2018-04-03
# 2                     NaN           NaN  3.023467  04    04  2018  2018-04-04
# 3                     NaN           NaN  6.006421  05    04  2018  2018-04-05
# 4                     NaN           NaN  0.539785  06    04  2018  2018-04-06
#
#    moving_minutes  elapsed_minutes       rest   avg_mph  time_since_last_act  \
# 0       46.466667        46.833333   0.366667  7.435788                -43.0
# 1       23.200000        33.400000  10.200000  8.887601                -25.0
# 2       27.366667        28.933333   1.566667  6.628231                -24.0
# 3       54.366667        68.166667  13.800000  6.628231                -36.0
# 4       19.216667        60.383333  41.166667  1.684461                -38.0
#
#    race
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
strava.total_elevation_gain.hist()

# %%
pd.crosstab(strava[strava.workout_type.notnull()].name,strava[strava.workout_type.notnull()].workout_type)
## I think 1 is run race, 11 is ride race, 0 is renamed run, 10 is renamed ride or photo or something
strava['race']=strava.workout_type.apply(lambda x: 1 if x in [1.0,11.0] else 0 )

# %%
strava.start_date.dtype,whoop.date.dtype
# Out:
# (dtype('O'), dtype('O'))

# %%
strava.start_date.head()
# Out:
# 0    2018-04-01 15:54:18+00:00
# 1    2018-04-03 10:35:19+00:00
# 2    2018-04-04 10:58:33+00:00
# 3    2018-04-05 10:29:13+00:00
# 4    2018-04-06 21:56:04+00:00
# Name: start_date, dtype: object

# %%
month_dict={'Jan':1,'Feb':2,'Mar':3,'Apr':4, 'May':5,'Jun':6,'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'Dec':12}
whoop['month']=whoop.date.apply(lambda x: month_dict[x[x.find(',')+1:x.find(',')+5].strip(" ")])
whoop['day']=whoop.date.apply(lambda x: x[-4:-2])
whoop['year']=whoop.month.apply(lambda x: 2018 if x!=1 else 2019)
whoop['date_string']=whoop.year.astype(str) + "-" + whoop.month.astype(str).str.strip(' ').str.zfill(2) + "-" + whoop.day.astype(str).str.strip(' ').str.zfill(2)

# %%
strava['day']=strava.start_date.apply(lambda x: x[8:10])
strava['month']=strava.start_date.apply(lambda x: x[5:7])
strava['year']=strava.start_date.apply(lambda x: x[:4])
strava['date_string']=strava.start_date.apply(lambda x: x[:10])
strava['moving_minutes']=strava.moving_time/60
strava['elapsed_minutes']=strava.elapsed_time/60
strava['rest']=strava.elapsed_minutes-strava.moving_minutes
## average speed is in meters/second - 2.237 to multiply to mph
strava['avg_mph']=strava.average_speed*2.237
strava['time_since_last_act']=(pd.to_datetime(strava.start_date)-pd.to_datetime(strava.start_date.shift(-1))).astype('timedelta64[h]')

# %%
## Checking to see if there are more than one run on each day (since that will complicate things)
multi_act=strava.groupby(['date_string','type']).type.count().sort_values(ascending=False).unstack()
multi_dates=multi_act[multi_act.Run>1].index.values
mult_df=strava[strava.date_string.isin(multi_dates)]
mult_df.start_date_local 
## way to do it is to sort on date and assign an activity number in strava, 
## reshape activities in whoop so it's activity unique rows, then merge on activity number and activity type and date
# Out:
# 73     2018-07-15 06:50:01+00:00
# 74     2018-07-15 07:39:48+00:00
# 75     2018-07-15 08:57:52+00:00
# 132    2018-10-03 06:27:25+00:00
# 133    2018-10-03 07:20:42+00:00
# 169    2018-12-25 16:51:37+00:00
# 170    2018-12-26 06:40:44+00:00
# Name: start_date_local, dtype: object

# %%
## Splitting into subsets by activity, then appending. Keeping the nulls for the first activity, but not the rest
act_1=whoop[['date','activity_1','activity_1_score']]
act_1.columns=['date','activity','score']
act_1['order']=1

act_2=whoop[['date','activity_2','activity_2_score']]
act_2.columns=['date','activity','score']
act_2['order']=2
act_2.dropna(inplace=True)

act_3=whoop[['date','activity_3','activity_3_score']]
act_3.columns=['date','activity','score']
act_3['order']=3
act_3.dropna(inplace=True)

all_acts=pd.concat([act_1,act_2,act_3])
all_desc=whoop.drop(['activity_1','activity_2','activity_3','activity_1_score','activity_2_score','activity_3_score'],
                   axis=1)
whoop_df=all_desc.merge(all_acts, how ='left',left_on='date',right_on='date')
whoop_df.head()
# Out:
# /Users/irarickman/anaconda2/envs/py35/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/irarickman/anaconda2/envs/py35/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/irarickman/anaconda2/envs/py35/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/irarickman/anaconda2/envs/py35/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/irarickman/anaconda2/envs/py35/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    strain  recovery  sleep_perf      sleep  rec_sleep            date  \
# 0    17.3      0.78        1.00  10.033333   8.666667  Today, Jan 4th
# 1    12.8      0.50        0.86   8.450000   9.866667    Thu, Jan 3rd
# 2    17.6      0.28        0.69   6.150000   8.916667    Wed, Jan 2nd
# 3    18.1      0.37        0.96   7.733333   8.066667    Tue, Jan 1st
# 4    18.1      0.37        0.96   7.733333   8.066667    Tue, Jan 1st
#
#   rec_color  activity_total  sleep_addition  pday_rec pday_rec_col  pday_acts  \
# 0     green               1        0.916667      0.50       yellow        1.0
# 1    yellow               1        2.116667      0.28          red        1.0
# 2       red               1        1.166667      0.37       yellow        2.0
# 3    yellow               2        0.316667      0.36       yellow        0.0
# 4    yellow               2        0.316667      0.36       yellow        0.0
#
#    pday_strain  pday_sleep  pday_sleep_perf  rolling_prev_2  \
# 0         17.3    8.450000             0.86             NaN
# 1         12.8    6.150000             0.69        7.300000
# 2         17.6    7.733333             0.96        6.941667
# 3         18.1    9.883333             1.00        8.808333
# 4         18.1    9.883333             1.00        8.808333
#
#    prev_strain_rec_gap  month day  year date_string       activity  score  \
# 0             0.335749      1   4  2019  2019-01-04        Running   15.4
# 1             0.338357      1   3  2019  2019-01-03  Weightlifting    7.0
# 2             0.480242      1   2  2019  2019-01-02        Running   16.3
# 3             0.514396      1   1  2019  2019-01-01        Running   15.7
# 4             0.514396      1   1  2019  2019-01-01       Activity    7.3
#
#    order
# 0      1
# 1      1
# 2      1
# 3      1
# 4      2

# %%
strava_keep=['miles','date_string','moving_minutes','elapsed_minutes','rest','avg_mph','time_since_last_act','start_date','day','total_elevation_gain','race']
strava_df=strava[strava.type=='Run'][strava_keep]
strava_df.start_date=pd.to_datetime(strava_df.start_date)
strava_df.sort_values('start_date',inplace=True)
strava_df['order']=strava_df.groupby('date_string').start_date.rank()
strava_df
# Out:
#          miles date_string  moving_minutes  elapsed_minutes       rest  \
# 0     5.758121  2018-04-01       46.466667        46.833333   0.366667
# 1     3.436741  2018-04-03       23.200000        33.400000  10.200000
# 2     3.023467  2018-04-04       27.366667        28.933333   1.566667
# 3     6.006421  2018-04-05       54.366667        68.166667  13.800000
# 5    10.203285  2018-04-08       74.450000        74.566667   0.116667
# 6     2.891053  2018-04-10       30.983333        31.050000   0.066667
# 7     5.017012  2018-04-11       39.100000        41.183333   2.083333
# 8     5.470923  2018-04-13       46.616667        50.016667   3.400000
# 9     3.514412  2018-04-14       30.933333        34.383333   3.450000
# 10    7.528593  2018-04-16       64.833333        68.816667   3.983333
# 48                  122.0     0    1.0
# 53                   58.0     0    1.0
# 54                   47.0     0    1.0
# 56                   80.0     0    1.0
# 58                   51.0     0    1.0
# 61                   23.0     0    1.0
# 62                   70.0     0    1.0
# 65                   52.0     0    1.0
# 66                   41.0     0    1.0
# 69                  104.0     0    1.0
# 70                   95.0     0    1.0
# 71                   16.0     0    1.0
# 72                   38.0     0    1.0
# 73                  250.0     1    1.0
# 75                   21.0     1    2.0
# 76                   43.0     0    1.0
# 79                   40.0     0    1.0
# 80                   50.0     0    1.0
# 83                   48.0     0    1.0
# 84                   53.0     0    1.0
# 86                   11.0     0    1.0
# 88                   49.0     0    1.0
# 90                   67.0     0    1.0
# 92                   52.0     0    1.0
# 94                   27.0     0    1.0
# ..                    ...   ...    ...
# 113                  40.0     0    1.0
# 115                  56.0     0    1.0
# 117                  13.0     0    1.0
# 119                  38.0     0    1.0
# 121                  41.0     0    1.0
# 123                  24.0     0    1.0
# 125                  31.0     0    1.0
# 129                  99.0     1    1.0
# 130                  57.0     0    1.0
# 131                 121.0     0    1.0
# 132                 146.0     0    1.0
# 133                  26.0     0    2.0
# 134                  90.0     1    1.0
# 135                  44.0     0    1.0
# 136                  46.0     0    1.0
# 137                  15.0     0    1.0
# 138                  76.0     0    1.0
# 139                  40.0     0    1.0
# 140                  47.0     0    1.0
# 141                  47.0     0    1.0
# 142                 104.0     0    1.0
# 144                  60.0     0    1.0
# 145                  29.0     0    1.0
# 146                  40.0     0    1.0
# 147                 246.0     1    1.0
# 148                 115.0     0    1.0
# 149                 131.0     0    1.0
# 150                  36.0     0    1.0
# 151                  30.0     0    1.0
# 152                  73.0     0    1.0
# 153                  30.0     0    1.0
# 154                  51.0     0    1.0
# 155                  48.0     0    1.0
# 156                  22.0     0    1.0
# 157                  21.0     0    1.0
# 158                  56.0     0    1.0
# 159                  63.0     0    1.0
# 160                  65.0     0    1.0
# 161                  35.0     0    1.0
# 162                  37.0     0    1.0
# 163                  45.0     0    1.0
# 164                  53.0     0    1.0
# 165                  56.0     0    1.0
# 166                  46.0     0    1.0
# 167                 106.0     0    1.0
# 168                  98.0     0    1.0
# 169                  59.0     0    1.0
# 170                  56.0     0    2.0
# 171                 140.0     0    1.0
# 172                  91.0     0    1.0
#
# [107 rows x 12 columns]

# %%
all_acts=whoop_df.merge(strava_df, left_on=['date_string','order'],right_on=['date_string','order'])
len(strava_df),whoop.date_string.nunique(),len(all_acts)
# Out:
# (107, 222, 81)

# %%
strava_df[strava_df.date_string<whoop.date_string.min()].shape[0]
dates=strava_df[strava_df.date_string>whoop.date_string.min()].date_string.values
[x for x in dates if x not in all_acts.date_string.values]
len(set(dates)),len(set(all_acts.date_string.values)) ## all the dates are in here!
all_acts.head()
# Out:
#    strain  recovery  sleep_perf     sleep  rec_sleep           date rec_color  \
# 0    19.1      0.16        0.63  5.583333   8.883333  Sun, Dec 30th       red
# 1    13.4      0.16        0.88  6.933333   7.900000  Fri, Dec 28th       red
# 2    14.4      0.18        1.00  7.266667   7.083333  Wed, Dec 26th       red
# 3    17.0      0.69        0.92  7.466667   8.133333  Mon, Dec 24th     green
# 4    19.2      0.82        1.00  9.600000   8.816667  Sat, Dec 22nd     green
#
#    activity_total  sleep_addition  pday_rec pday_rec_col  pday_acts  \
# 0               1        1.133333      0.30          red        1.0
# 1               1        0.150000      0.59       yellow        0.0
# 2               1       -0.666667       NaN         none        1.0
# 3               1        0.383333      0.45       yellow        0.0
# 4               1        1.066667      0.44       yellow        0.0
#
#    pday_strain  pday_sleep  pday_sleep_perf  rolling_prev_2  \
# 0         19.1    6.950000             0.83        6.266667
# 1         13.4    7.366667             1.00        7.150000
# 2         14.4         NaN              NaN             NaN
# 3         17.0    9.216667             1.00        8.341667
# 4         19.2    4.266667             0.41        6.933333
#
#    prev_strain_rec_gap  month day_x  year date_string            activity  \
# 0             0.622705     12    30  2018  2018-12-30            Activity
# 1             0.057343     12    28  2018  2018-12-28             Running
# 2                  NaN     12    26  2018  2018-12-26  Functional Fitness
# 3             0.371256     12    24  2018  2018-12-24             Running
# 4             0.487536     12    22  2018  2018-12-22             Running
#
#    score  order     miles  moving_minutes  elapsed_minutes      rest  \
# 0   18.5      1  7.667283       64.016667        69.700000  5.683333
# 1   10.7      1  3.377089       37.016667        40.766667  3.750000
# 2   13.4      1  3.168619       29.133333        29.400000  0.266667
# 3   15.2      1  5.007877       39.616667        41.166667  1.550000
# 4   18.0      1  7.808707       62.216667        64.016667  1.800000
#
#     avg_mph  time_since_last_act          start_date day_y  \
# 0  7.187481                  NaN 2018-12-30 21:57:17    30
# 1  5.473939                -52.0 2018-12-28 18:29:28    28
# 2  6.525329                -14.0 2018-12-26 00:51:37    26
# 3  7.585667                -26.0 2018-12-24 23:29:21    24
# 4  7.529742                -54.0 2018-12-22 18:22:45    22
#
#    total_elevation_gain  race
# 0                  91.0     0
# 1                 140.0     0
# 2                  59.0     0
# 3                  98.0     0
# 4                 106.0     0

# %%
X_train.isnull().sum()
# Out:
# recovery                0
# sleep_perf              0
# sleep                   0
# rec_sleep               0
# sleep_addition          0
# pday_rec                2
# pday_acts               0
# pday_strain             0
# pday_sleep              3
# pday_sleep_perf         3
# rolling_prev_2          3
# prev_strain_rec_gap     2
# miles                   0
# moving_minutes          0
# elapsed_minutes         0
# rest                    0
# avg_mph                 0
# time_since_last_act     0
# total_elevation_gain    0
# race                    0
# dtype: int64

# %%
## can dummy the type later - impute missing as average later, limit to runs, clean up collinearity
all_acts.dropna(inplace=True)
X=all_acts.drop(['strain','date','rec_color','pday_rec_col','activity_total','month','day_x','year','date_string','activity','score',
                 'order','start_date','day_y'],axis=1)
y=all_acts.score
X_train,X_test,y_train,y_test=tts(X,y)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
X_train=sm.add_constant(X_train)
lr=sm.OLS(y_train,X_train)
res=lr.fit()
res.summary()
# Out:
# (55, 20) (55,)
# (19, 20) (19,)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     4.957
# Date:                Tue, 05 Feb 2019   Prob (F-statistic):           2.53e-05
# Time:                        22:57:58   Log-Likelihood:                -104.61
# No. Observations:                  55   AIC:                             243.2
# Df Residuals:                      38   BIC:                             277.3
# Df Model:                          16
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.3764      0.524     -0.719      0.477      -1.436       0.683
# recovery                 0.3365      1.161      0.290      0.773      -2.013       2.686
# sleep_perf              18.7975     35.806      0.525      0.603     -53.687      91.282
# sleep                   -1.9904      3.282     -0.606      0.548      -8.635       4.654
# rec_sleep               -1.2674      0.989     -1.282      0.208      -3.269       0.734
# sleep_addition           1.6501      3.336      0.495      0.624      -5.104       8.404
# pday_rec                 0.2937      0.863      0.341      0.735      -1.453       2.040
# pday_acts                0.4171      0.603      0.692      0.493      -0.804       1.638
# pday_strain              0.7319      0.161      4.554      0.000       0.407       1.057
# pday_sleep               1.1733      0.986      1.190      0.242      -0.823       3.170
# pday_sleep_perf        -11.9569      7.160     -1.670      0.103     -26.452       2.538
# rolling_prev_2          -0.4085      1.241     -0.329      0.744      -2.920       2.103
# prev_strain_rec_gap     -0.2584      0.861     -0.300      0.766      -2.002       1.485
# miles                   -1.9690      1.601     -1.230      0.226      -5.210       1.272
# moving_minutes           0.1960      0.130      1.510      0.139      -0.067       0.459
# elapsed_minutes          0.0740      0.065      1.145      0.260      -0.057       0.205
# rest                    -0.1220      0.072     -1.687      0.100      -0.268       0.024
# avg_mph                  1.5281      0.892      1.713      0.095      -0.278       3.334
# time_since_last_act     -0.0140      0.010     -1.376      0.177      -0.035       0.007
# total_elevation_gain     0.0209      0.011      1.872      0.069      -0.002       0.043
# race                     1.1229      1.462      0.768      0.447      -1.837       4.083
# ==============================================================================
# Omnibus:                       32.460   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.663
# Skew:                          -1.676   Prob(JB):                     2.50e-19
# Kurtosis:                       8.113   Cond. No.                     7.49e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.23e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
## trying just pday strain and recovery and sleep
X=all_acts[['pday_strain','recovery','sleep_perf','sleep_addition']]
y=all_acts.score
X_train,X_test,y_train,y_test=tts(X,y)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
X_train=sm.add_constant(X_train)
lr=sm.OLS(y_train,X_train)
res=lr.fit()
res.summary()
# Out:
# (55, 4) (55,)
# (19, 4) (19,)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     20.63
# Date:                Tue, 05 Feb 2019   Prob (F-statistic):           4.34e-10
# Time:                        22:59:26   Log-Likelihood:                -108.27
# No. Observations:                  55   AIC:                             226.5
# Df Residuals:                      50   BIC:                             236.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0853      2.217      0.038      0.969      -4.369       4.539
# pday_strain        1.0087      0.111      9.068      0.000       0.785       1.232
# recovery          -0.1818      0.950     -0.191      0.849      -2.090       1.726
# sleep_perf        -2.3604      1.793     -1.317      0.194      -5.961       1.241
# sleep_addition    -0.5015      0.360     -1.394      0.169      -1.224       0.221
# ==============================================================================
# Omnibus:                       53.818   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.990
# Skew:                          -2.651   Prob(JB):                     5.84e-62
# Kurtosis:                      12.744   Cond. No.                         177.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Feature ideas
# * Miles above average for last two weeks
# * Elevation gain/mile
# * rest as % of total time
# * speed above average for last two weeks
# *

# %% [markdown]
# ## Next steps
#
# 1. Make a few more features
# 2. Attach whoop to strava
# 3. Run linear reg - see how it does

# %%
## maybe logarithimc?
sns.regplot(whoop.sleep_perf, whoop.recovery)
# Out:
# /Users/irarickman/anaconda2/envs/py35/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(whoop.sleep, whoop.recovery)
# Out:
# /Users/irarickman/anaconda2/envs/py35/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
